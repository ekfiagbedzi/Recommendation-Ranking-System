# %%
# convert price dtype to float
products.price = products.price.str.replace(
    "£", "").str.replace(",", "").astype(float)

# %%
# convert create_time dtype to float
products.create_time = pd.to_datetime(products.create_time)

# %%
# check dtypes again
products.dtypes
# Out:
# Unnamed: 0                      int64
# id                             object
# product_name                   object
# category                       object
# product_description            object
# price                         float64
# location                       object
# url                            object
# page_id                         int64
# create_time            datetime64[ns]
# dtype: object

# %%
# check for obvious missing values
products.isnull().sum()
# Out:
# Unnamed: 0             0
# id                     0
# product_name           0
# category               0
# product_description    0
# price                  0
# location               0
# url                    0
# page_id                0
# create_time            0
# dtype: int64

# %%
# load images data
images = pd.read_csv("../Images.csv", index_col=2)
images.head()
# Out:
#                                       Unnamed: 0  \
# product_id
# 5f5f57d7-778f-4336-bb10-b43863418c8c           0
# 5f5f57d7-778f-4336-bb10-b43863418c8c           1
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4           2
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4           3
# 8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf           4
#
#                                                                         id  \
# product_id
# 5f5f57d7-778f-4336-bb10-b43863418c8c  912bb259-3ad9-457b-9db1-ce1da9016057
# 5f5f57d7-778f-4336-bb10-b43863418c8c  b166d305-b852-4bdd-83f4-465b20da94fa
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4  68f5a29d-0075-4d60-81c1-ab684a82e50c
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4  f6a309d7-d247-446a-9b5e-aceefdd4334d
# 8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf  2c2b3a6f-15b3-4289-937a-15482d9f5781
#
#                                                                             bucket_link  \
# product_id
# 5f5f57d7-778f-4336-bb10-b43863418c8c  https://aicore-projects-datasets-prod.s3.eu-we...
# ...

# %%
products
# Out:
#       Unnamed: 0                                    id  \
# 0              0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1              1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2              2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3              3  59948726-29be-4b35-ade5-bb2fd7331856
# 4              4  16dbc860-696e-4cda-93f6-4dd4926573fb
# ...          ...                                   ...
# 7151        7151  c4148656-78a9-4f3e-b393-134fdc5ef900
# 7152        7152  564e3411-768d-4250-a624-b119d696f103
# 7153        7153  2b0a652b-46a2-4297-b619-5efeeb222787
# 7154        7154  719fd40a-870e-4144-b324-55dff2e66fb4
# 7155        7155  86d1806b-5575-4a7e-9160-f24f12be6c95
#
#                                            product_name  \
# 0     Mirror wall art | in Wokingham, Berkshire | Gu...
# 1     Stainless Steel Food Steamer | in Inverness, H...
# 2     Sun loungers | in Skegness, Lincolnshire | Gum...
# 3     Coffee side table from Ammunition ammo box hai...
# ...

# %%
common = list(set(images.product_id).intersection(set(products.id)))
common
# Out:
# ['56d4cfe1-274e-44e5-82eb-21f8ddf921ec',
#  '5cb39c15-3bd1-4cac-bbf7-47791a123afe',
#  'fece01ae-1b9c-4597-bec2-44da2949ada9',
#  '4b85772a-d382-4043-8723-60abb900b706',
#  'a285319b-8bb1-4195-94a4-4c91b26b2aa6',
#  '54d72a9d-4c7a-4419-b845-b690057c9092',
#  '5806a069-e9d2-4bb4-aed9-7c18892b8e99',
#  '4410ba94-d204-4371-95ac-624bc7205ae1',
#  'e51c3920-472e-4ee5-9813-d03f9d83c536',
#  '3e29ed80-ccf8-4bbc-9318-3da0d5e5e6cb',
#  'ea1d2e42-bb0b-4931-991d-29b3afb60b06',
#  'a86ddaa4-0773-4c9e-a7b0-2e1dd003a996',
#  '94bfe4a9-0722-4c55-96ed-edd6487fdcb0',
#  '52060fbb-b2e4-40b6-a540-c6f93f10b829',
#  'c7de92e3-406f-4e7e-822b-8690fff71771',
#  'b4b54862-a72d-47e6-ac2f-09ee3aa8a3cf',
#  'eb9c378c-9098-42ba-bf58-f0bbbb4b0b5a',
#  'c767b599-b9ad-40ff-bfe2-f4646d960aec',
#  '045c0527-9401-4a8f-b8a9-a9385659b3d4',
#  'd01d036d-32a1-4069-a68e-5f0cf0140690',
#  '6514f5b0-86f7-4ca5-8344-1ee5d46cbb73',
#  '61a5541e-b86d-4f7f-9d58-4215a24fa5d0',
#  'd639cbd6-31d4-4c4e-9ca5-724af994fee0',
# ...

# %%
products.set_index("id", inplace=True)

# %%
images.loc[common]
products.loc[common]
# Out:
#                                       Unnamed: 0  \
# id
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec        1795
# 5cb39c15-3bd1-4cac-bbf7-47791a123afe        1420
# fece01ae-1b9c-4597-bec2-44da2949ada9        4272
# 4b85772a-d382-4043-8723-60abb900b706        5473
# a285319b-8bb1-4195-94a4-4c91b26b2aa6        3061
# ...                                          ...
# 479f562a-92c7-44b2-a7d4-b21f211b6475        1692
# 32bcdf78-f1d6-46ad-a12e-6fc6f29689e8        1238
# 26d417c8-5362-4784-9c78-286049d6399f        1021
# 82f09c12-a151-450e-923e-12c2ea83fbb2          70
# bcaf3b54-9c97-459f-8104-d40f78efc598        4817
#
#                                                                            product_name  \
# id
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec  Peter Rabbit 50p Coin | in Bradford, West York...
# 5cb39c15-3bd1-4cac-bbf7-47791a123afe  (NEW) SAINSBURY’S BLACK SUEDE BOOTS (SIZE 5) |...
# fece01ae-1b9c-4597-bec2-44da2949ada9  DRAGON WARS DVD-REGION 2 PAL-CERT.12-AUDIO 5.1...
# ...

# %%
image_list = os.listdir("/../home/ubuntu/Recommendation-Ranking-System/cleaned_images")
image_list = set([i.split("_")[0] for i in image_list])
image_list
# Out:
# {'6c1b23bc-51cd-4d14-8f4b-2fcfcb273d32',
#  '7217f9cf-e1a6-40f4-83e0-677339d21ab0',
#  '1d960f21-f416-4faa-95fe-00639c7a74ff',
#  '6e02fe9d-2f35-4e0a-a9fa-fb1c9eec6a5b',
#  '5c12fb5f-7940-4ddb-a0cb-7e2707104f21',
#  'dc33b004-427f-438a-811c-ea43a684f87f',
#  '6c1c796c-faba-407a-a21b-ac1aece73b0a',
#  '01acdc5d-360e-4a44-a07d-ded2ac842d2d',
#  '764719da-a424-486c-85a6-ebfa43d99a8d',
#  '2c5c7f57-b4bd-4be6-9bff-e9414d607377',
#  '957a7117-9d06-4821-8db1-f9bd263c4430',
#  'ed08807a-f9f4-4d48-8b11-a84b1e206de2',
#  'b9f86485-d5ae-4be4-af91-d5045906738c',
#  '5add577c-6c71-4753-abba-1fa3a26a18d7',
#  '77c93ea8-f024-4ac9-9b35-4858e07909c1',
#  '8ea590d5-e585-4371-9cf0-0d2ef59986d1',
#  '3497a271-1092-461d-9625-7550d057f0fc',
#  '43e88a3a-24bd-41e8-9fab-53e8cd73671b',
#  'bb129a36-8ed2-4beb-87a5-47281fa9c8ea',
#  'b07da59c-4675-45b2-aa4e-41263ee15f7e',
#  'fa098e72-9aa3-49cf-9ad3-a8dc4dc1b94b',
#  '2c109682-6949-4481-9e92-1a01a533d565',
#  '79eeb4b9-78a6-4e79-ac21-190a8e9f7845',
# ...

# %%
aaa = image_list.intersection(set(images.product_id))

# %%
# find nnumber of similar ids between products data and images data
products_unique = set(products.id)
images_unique = set(images.id)
len(products_unique.intersection(aaa))
# Out:
# 0

# %%
products
# Out:
#                                       Unnamed: 0  \
# id
# 243809c0-9cfc-4486-ad12-3b7a16605ba9           0
# 1c58d3f9-8b93-47ea-9415-204fcc2a22e6           1
# 860673f1-57f6-47ba-8d2f-13f9e05b8f9a           2
# 59948726-29be-4b35-ade5-bb2fd7331856           3
# 16dbc860-696e-4cda-93f6-4dd4926573fb           4
# ...                                          ...
# c4148656-78a9-4f3e-b393-134fdc5ef900        7151
# 564e3411-768d-4250-a624-b119d696f103        7152
# 2b0a652b-46a2-4297-b619-5efeeb222787        7153
# 719fd40a-870e-4144-b324-55dff2e66fb4        7154
# 86d1806b-5575-4a7e-9160-f24f12be6c95        7155
#
#                                                                            product_name  \
# id
# 243809c0-9cfc-4486-ad12-3b7a16605ba9  Mirror wall art | in Wokingham, Berkshire | Gu...
# 1c58d3f9-8b93-47ea-9415-204fcc2a22e6  Stainless Steel Food Steamer | in Inverness, H...
# 860673f1-57f6-47ba-8d2f-13f9e05b8f9a  Sun loungers | in Skegness, Lincolnshire | Gum...
# ...

# %%
pd.concat([images.loc[common], products.loc[common]])
# Out:
#                                       Unnamed: 0  \
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec        3172
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec        3173
# 5cb39c15-3bd1-4cac-bbf7-47791a123afe        2498
# 5cb39c15-3bd1-4cac-bbf7-47791a123afe        2499
# fece01ae-1b9c-4597-bec2-44da2949ada9        7497
# ...                                          ...
# 479f562a-92c7-44b2-a7d4-b21f211b6475        1692
# 32bcdf78-f1d6-46ad-a12e-6fc6f29689e8        1238
# 26d417c8-5362-4784-9c78-286049d6399f        1021
# 82f09c12-a151-450e-923e-12c2ea83fbb2          70
# bcaf3b54-9c97-459f-8104-d40f78efc598        4817
#
#                                                                         id  \
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec  c6dc1e8e-0293-4ec8-b984-0bb70a428083
# 56d4cfe1-274e-44e5-82eb-21f8ddf921ec  a5d2fa44-26a0-4200-8a1c-3ed04bdc2bac
# 5cb39c15-3bd1-4cac-bbf7-47791a123afe  95a58986-8f77-4b64-9bf1-2cadaa72815b
# ...

# %%
images.reset_index().product_id.duplicated(keep="first")
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 12599     True
# 12600    False
# 12601     True
# 12602    False
# 12603     True
# Name: product_id, Length: 12604, dtype: bool

# %%
images.reset_index().product_id
# Out:
# 0        5f5f57d7-778f-4336-bb10-b43863418c8c
# 1        5f5f57d7-778f-4336-bb10-b43863418c8c
# 2        c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 3        c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 4        8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf
#                          ...
# 12599    2b0a652b-46a2-4297-b619-5efeeb222787
# 12600    719fd40a-870e-4144-b324-55dff2e66fb4
# 12601    719fd40a-870e-4144-b324-55dff2e66fb4
# 12602    86d1806b-5575-4a7e-9160-f24f12be6c95
# 12603    86d1806b-5575-4a7e-9160-f24f12be6c95
# Name: product_id, Length: 12604, dtype: object

# %%
products.page_id.unique().shape
# Out:
# (7156,)

# %%
products
# Out:
#                                       Unnamed: 0  \
# id
# 243809c0-9cfc-4486-ad12-3b7a16605ba9           0
# 1c58d3f9-8b93-47ea-9415-204fcc2a22e6           1
# 860673f1-57f6-47ba-8d2f-13f9e05b8f9a           2
# 59948726-29be-4b35-ade5-bb2fd7331856           3
# 16dbc860-696e-4cda-93f6-4dd4926573fb           4
# ...                                          ...
# c4148656-78a9-4f3e-b393-134fdc5ef900        7151
# 564e3411-768d-4250-a624-b119d696f103        7152
# 2b0a652b-46a2-4297-b619-5efeeb222787        7153
# 719fd40a-870e-4144-b324-55dff2e66fb4        7154
# 86d1806b-5575-4a7e-9160-f24f12be6c95        7155
#
#                                                                            product_name  \
# id
# 243809c0-9cfc-4486-ad12-3b7a16605ba9  Mirror wall art | in Wokingham, Berkshire | Gu...
# 1c58d3f9-8b93-47ea-9415-204fcc2a22e6  Stainless Steel Food Steamer | in Inverness, H...
# 860673f1-57f6-47ba-8d2f-13f9e05b8f9a  Sun loungers | in Skegness, Lincolnshire | Gum...
# ...

# %%
# drop first product_id duplicates and concat with products dataframe axis=1
## drop last product_id duplicates and concat with products dataframe axis=1
### combine both dataframes axis =0
#### drop duplicate page_ids and keep only first

# %%
# import libraries
import os

import pandas as pd

# %%
# load both image and product dataframes
images = pd.read_csv("../Images.csv")
images
# Out:
#        Unnamed: 0                                    id  \
# 0               0  912bb259-3ad9-457b-9db1-ce1da9016057
# 1               1  b166d305-b852-4bdd-83f4-465b20da94fa
# 2               2  68f5a29d-0075-4d60-81c1-ab684a82e50c
# 3               3  f6a309d7-d247-446a-9b5e-aceefdd4334d
# 4               4  2c2b3a6f-15b3-4289-937a-15482d9f5781
# ...           ...                                   ...
# 12599       12599  cdec1c5c-c4b1-42db-afbe-3fa68ea4b87d
# 12600       12600  dc99e40f-6b15-494d-9fb7-f0d02e9781f9
# 12601       12601  c8488028-bf07-4258-a4c2-56d2fe387835
# 12602       12602  c6113145-89c8-47cd-9211-38f29d016cc7
# 12603       12603  ed2aaf88-616c-4e6b-af49-bbdf7c0fbd06
#
#                                  product_id  \
# 0      5f5f57d7-778f-4336-bb10-b43863418c8c
# 1      5f5f57d7-778f-4336-bb10-b43863418c8c
# 2      c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 3      c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 4      8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf
# ...

# %%
# load products dataframe
products = pd.read_csv("../Products.csv", lineterminator="\n")
products
# Out:
#       Unnamed: 0                                    id  \
# 0              0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1              1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2              2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3              3  59948726-29be-4b35-ade5-bb2fd7331856
# 4              4  16dbc860-696e-4cda-93f6-4dd4926573fb
# ...          ...                                   ...
# 7151        7151  c4148656-78a9-4f3e-b393-134fdc5ef900
# 7152        7152  564e3411-768d-4250-a624-b119d696f103
# 7153        7153  2b0a652b-46a2-4297-b619-5efeeb222787
# 7154        7154  719fd40a-870e-4144-b324-55dff2e66fb4
# 7155        7155  86d1806b-5575-4a7e-9160-f24f12be6c95
#
#                                            product_name  \
# 0     Mirror wall art | in Wokingham, Berkshire | Gu...
# 1     Stainless Steel Food Steamer | in Inverness, H...
# 2     Sun loungers | in Skegness, Lincolnshire | Gum...
# 3     Coffee side table from Ammunition ammo box hai...
# ...

# %%
# check for obvious missing values
products.isnull().sum()
# Out:
# Unnamed: 0             0
# id                     0
# product_name           0
# category               0
# product_description    0
# price                  0
# location               0
# url                    0
# page_id                0
# create_time            0
# dtype: int64

# %%
# check for frequencies of product_ids
images.product_id.describe()

# %% [markdown]
# The highest occuring product ids has a frequency of 2, and they have different
# image ids therefore I can keep both first and last occurences to have more data

# %%
# make corresponding ids the indices of both dataframes
images.set_index("product_id", inplace=True)
products.set_index("id", inplace=True)

# %%
# drop first occurences of duplicates in both dataframes
images_df1 = images[images.index.duplicated(keep="first")]
products = products[~products.index.duplicated(keep="first")]

# %%
# extract common ids between the two dataframes
common_ids= list(set(images_df1.index).intersection(set(products.index)))
len(common_ids)
# Out:
# 5552

# %%
# combine dataframes with first occurences kept
combined_df1 = pd.concat(
    [images_df1.loc[common_ids], products.loc[common_ids]], axis=1)
combined_df1
# Out:
#                                       Unnamed: 0  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511        1924
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8        5688
# c543b73b-4727-45b5-9143-4f8e603275b1        7783
# 8d083154-054a-4e40-a430-aded9cb154b3        1244
# a613a404-70fc-4f9b-a80b-8a0a073547bd        8864
# ...                                          ...
# 05c3093e-f19e-4188-9207-247e59854afb       12095
# 67994b13-0014-42ce-9628-a8123ace227c        8161
# d673ff82-3238-4987-9f7d-3c3b6a89a730        2574
# e4e047f4-70cd-4f39-973b-f5647780c874        8799
# fd6d87ea-b274-41a9-806e-8286dfb622e7       10185
#
#                                                                         id  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511  c134f7f8-bd14-4f3b-8afc-ade56279add0
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8  1caf2fa7-b3d0-4cdd-87dd-03f81218bf0d
# c543b73b-4727-45b5-9143-4f8e603275b1  c335994b-7aa8-4e6e-977e-1ddf0e8d5f90
# ...

# %%
# drop last occurences of duplicates in both dataframes
images_df2 = images[images.index.duplicated(keep="last")]
products = products[~products.index.duplicated(keep="last")]

# %%
# combine dataframes with last occurences kept
combined_df2 = pd.concat([images_df2.loc[common_ids], products.loc[common_ids]], axis=1)
combined_df2
# Out:
#                                       Unnamed: 0  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511        1923
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8        5687
# c543b73b-4727-45b5-9143-4f8e603275b1        7782
# 8d083154-054a-4e40-a430-aded9cb154b3        1243
# a613a404-70fc-4f9b-a80b-8a0a073547bd        8863
# ...                                          ...
# 05c3093e-f19e-4188-9207-247e59854afb       12094
# 67994b13-0014-42ce-9628-a8123ace227c        8160
# d673ff82-3238-4987-9f7d-3c3b6a89a730        2573
# e4e047f4-70cd-4f39-973b-f5647780c874        8798
# fd6d87ea-b274-41a9-806e-8286dfb622e7       10184
#
#                                                                         id  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511  57728b67-d3ea-4fc9-96a1-58619d6025a6
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8  1264b570-6c5f-4e66-ae3b-1da54e0a8a7d
# c543b73b-4727-45b5-9143-4f8e603275b1  1f4a347d-af18-42d5-b378-09d2e5381753
# ...

# %%
# join the two dataframes
combined = pd.concat([combined_df1, combined_df2])

# %%
# keep only first of duplicates
combined.drop_duplicates(subset=["bucket_link"], keep="first", inplace=True)
combined
# Out:
#                                       Unnamed: 0  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511        1924
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8        5688
# c543b73b-4727-45b5-9143-4f8e603275b1        7783
# 8d083154-054a-4e40-a430-aded9cb154b3        1244
# a613a404-70fc-4f9b-a80b-8a0a073547bd        8864
# ...                                          ...
# 05c3093e-f19e-4188-9207-247e59854afb       12094
# 67994b13-0014-42ce-9628-a8123ace227c        8160
# d673ff82-3238-4987-9f7d-3c3b6a89a730        2573
# e4e047f4-70cd-4f39-973b-f5647780c874        8798
# fd6d87ea-b274-41a9-806e-8286dfb622e7       10184
#
#                                                                         id  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511  c134f7f8-bd14-4f3b-8afc-ade56279add0
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8  1caf2fa7-b3d0-4cdd-87dd-03f81218bf0d
# c543b73b-4727-45b5-9143-4f8e603275b1  c335994b-7aa8-4e6e-977e-1ddf0e8d5f90
# ...

# %%
# reset index and name it product ids
## Drop unnamed columns and extra create time column
### check and change various dtypes into correct ones
#### add images to the table as numpy arrays
##### store the dataframe as a pickle file
# Out:
# Index(['Unnamed: 0', 'id', 'bucket_link', 'image_ref', 'create_time',
#        'Unnamed: 0', 'product_name', 'category', 'product_description',
#        'price', 'location', 'url', 'page_id', 'create_time'],
#       dtype='object')

# %%
images
# Out:
#        Unnamed: 0                                    id  \
# 0               0  912bb259-3ad9-457b-9db1-ce1da9016057
# 1               1  b166d305-b852-4bdd-83f4-465b20da94fa
# 2               2  68f5a29d-0075-4d60-81c1-ab684a82e50c
# 3               3  f6a309d7-d247-446a-9b5e-aceefdd4334d
# 4               4  2c2b3a6f-15b3-4289-937a-15482d9f5781
# ...           ...                                   ...
# 12599       12599  cdec1c5c-c4b1-42db-afbe-3fa68ea4b87d
# 12600       12600  dc99e40f-6b15-494d-9fb7-f0d02e9781f9
# 12601       12601  c8488028-bf07-4258-a4c2-56d2fe387835
# 12602       12602  c6113145-89c8-47cd-9211-38f29d016cc7
# 12603       12603  ed2aaf88-616c-4e6b-af49-bbdf7c0fbd06
#
#                                  product_id  \
# 0      5f5f57d7-778f-4336-bb10-b43863418c8c
# 1      5f5f57d7-778f-4336-bb10-b43863418c8c
# 2      c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 3      c2c8949f-3cde-4651-a234-4a4a1b2a9ad4
# 4      8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf
# ...

# %%
combined
# Out:
#                                       Unnamed: 0  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511        1924
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8        5688
# c543b73b-4727-45b5-9143-4f8e603275b1        7783
# 8d083154-054a-4e40-a430-aded9cb154b3        1244
# a613a404-70fc-4f9b-a80b-8a0a073547bd        8864
# ...                                          ...
# 05c3093e-f19e-4188-9207-247e59854afb       12094
# 67994b13-0014-42ce-9628-a8123ace227c        8160
# d673ff82-3238-4987-9f7d-3c3b6a89a730        2573
# e4e047f4-70cd-4f39-973b-f5647780c874        8798
# fd6d87ea-b274-41a9-806e-8286dfb622e7       10184
#
#                                                                         id  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511  c134f7f8-bd14-4f3b-8afc-ade56279add0
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8  1caf2fa7-b3d0-4cdd-87dd-03f81218bf0d
# c543b73b-4727-45b5-9143-4f8e603275b1  c335994b-7aa8-4e6e-977e-1ddf0e8d5f90
# ...

# %%
images
# Out:
#                                       Unnamed: 0  \
# product_id
# 5f5f57d7-778f-4336-bb10-b43863418c8c           0
# 5f5f57d7-778f-4336-bb10-b43863418c8c           1
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4           2
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4           3
# 8292aa4e-7f1b-4655-bf0e-f1f2c9e3ffaf           4
# ...                                          ...
# 2b0a652b-46a2-4297-b619-5efeeb222787       12599
# 719fd40a-870e-4144-b324-55dff2e66fb4       12600
# 719fd40a-870e-4144-b324-55dff2e66fb4       12601
# 86d1806b-5575-4a7e-9160-f24f12be6c95       12602
# 86d1806b-5575-4a7e-9160-f24f12be6c95       12603
#
#                                                                         id  \
# product_id
# 5f5f57d7-778f-4336-bb10-b43863418c8c  912bb259-3ad9-457b-9db1-ce1da9016057
# 5f5f57d7-778f-4336-bb10-b43863418c8c  b166d305-b852-4bdd-83f4-465b20da94fa
# c2c8949f-3cde-4651-a234-4a4a1b2a9ad4  68f5a29d-0075-4d60-81c1-ab684a82e50c
# ...

# %%
combined.loc["5f5f57d7-778f-4336-bb10-b43863418c8c", :]
# Out:
#                                       Unnamed: 0  \
# 5f5f57d7-778f-4336-bb10-b43863418c8c           1
# 5f5f57d7-778f-4336-bb10-b43863418c8c           0
#
#                                                                         id  \
# 5f5f57d7-778f-4336-bb10-b43863418c8c  b166d305-b852-4bdd-83f4-465b20da94fa
# 5f5f57d7-778f-4336-bb10-b43863418c8c  912bb259-3ad9-457b-9db1-ce1da9016057
#
#                                                                             bucket_link  \
# 5f5f57d7-778f-4336-bb10-b43863418c8c  https://aicore-projects-datasets-prod.s3.eu-we...
# 5f5f57d7-778f-4336-bb10-b43863418c8c  https://aicore-projects-datasets-prod.s3.eu-we...
#
#                                              image_ref create_time  \
# 5f5f57d7-778f-4336-bb10-b43863418c8c  9vgAAOSw8sRiE5dE  2022-02-26
# 5f5f57d7-778f-4336-bb10-b43863418c8c  koQAAOSwhZRiE5dD  2022-02-26
#
#                                       Unnamed: 0  \
# 5f5f57d7-778f-4336-bb10-b43863418c8c          12
# ...

# %%
combined[combined.id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, bucket_link, image_ref, create_time, Unnamed: 0, product_name, category, product_description, price, location, url, page_id, create_time]
# Index: []

# %%
combined
# Out:
#                                       Unnamed: 0  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511        1924
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8        5688
# c543b73b-4727-45b5-9143-4f8e603275b1        7783
# 8d083154-054a-4e40-a430-aded9cb154b3        1244
# a613a404-70fc-4f9b-a80b-8a0a073547bd        8864
# ...                                          ...
# 05c3093e-f19e-4188-9207-247e59854afb       12094
# 67994b13-0014-42ce-9628-a8123ace227c        8160
# d673ff82-3238-4987-9f7d-3c3b6a89a730        2573
# e4e047f4-70cd-4f39-973b-f5647780c874        8798
# fd6d87ea-b274-41a9-806e-8286dfb622e7       10184
#
#                                                                         id  \
# bf3f786b-dc54-4d49-bb16-7f5dd4e28511  c134f7f8-bd14-4f3b-8afc-ade56279add0
# f8a64768-a76b-4b12-bbb5-ac6bbace6de8  1caf2fa7-b3d0-4cdd-87dd-03f81218bf0d
# c543b73b-4727-45b5-9143-4f8e603275b1  c335994b-7aa8-4e6e-977e-1ddf0e8d5f90
# ...

# %%
5552+5552
# Out:
# 11104
